# %% [markdown]
# ## ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Project 3: NLP Classification: Subreddit Pepsi vs Coca-Cola | Part 2: Vectorizer

# %% [markdown]
# ---
#
# [README](../README.md) | [Part 1: EDA](01_EDA.ipynb) | **Part 2: Vectorizer** | [Part 3: Vectorizer Performance](03_Vectorizer_Performance.ipynb) | [Part 4: Model Tuning](04_Model_Tuning.ipynb)
#
# ---

# %% [markdown]
# ### Introduction
# From [Part 1: EDA](01_EDA.ipynb), we obtained `subreddit_pepsi_vs_cocacola.csv_clean`, which has been cleaned. In this part, we focus on tuning the hyperparameters of two vectorizers: **CountVectorizer** and **TfidfVectorizer**, while using default settings for the model. Our goal is to analyze how the hyperparameters of the vectorizers affect model performance.
#
# The **CountVectorizer** represents each document by the frequency of words (tokens) in the text. While **TfidfVectorizer** measures the relative importance of a word in a document by balancing its frequency in that document (Term Frequency) with how rare it is across all documents (Inverse Document Frequency). The latter vectorizer often provides better results, especially when distinguishing key terms in large corpora.

# %% [markdown]
# ### Import

# %%
# Data manipulation and plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# NLP tools
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Model selection and evaluation
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix, recall_score, precision_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Classifiers
from sklearn.naive_bayes import MultinomialNB 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# Time utility
import time
from joblib import parallel_backend

# Set seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ### Data Preparation

# %%
df = pd.read_csv('../data/subreddit_pepsi_vs_cocacola_clean.csv')          # Load Data
df.head(1)                                                                 # Check first row
# Out:
#          title  score       id                                     url  \
# 0  Wall clock.     17  1godhom  https://www.reddit.com/gallery/1godhom
#
#    comms_num          created  \
# 0          1  11/11/2024 5:58
#
#                                                 body  is_pepsi  \
# 0  I'm trying to locate a value for this clock. I...         0
#
#                                           title_body  title_body_length  \
# 0  Wall clock. I'm trying to locate a value for t...                220
#
#    title_body_word_count
# 0                     39

# %%
df.shape
# Out:
# (1958, 11)

# %%
# Set Features and Target

X = df['title_body']
y = df['is_pepsi']

# Split the data to training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X
                                                    , y
                                                    , test_size = 0.2
                                                    , stratify = y
                                                   )

# %% [markdown]
# ### Vectorizer
# - We focus on two types of vectorizers: **CountVectorizer** and **TfidfVectorizer**, which share the same set of parameters.
# - First, converting the text to lowercase and removing words related to **Pepsi** and **Coca-Cola** are mandatory steps.
# - The other parameters we will adjust for comparison are:
#     - Removes English Stopwords or not
#     - Maximum features: 3000, 5000, or None
#     - N-gram length: whether to include bigrams or not
#     - Minimum document frequency (min_df): 2, or 3
#     - Maximum document frequency (max_df): 0.8 or 0.9

# %%
# Related words are words that can easily identify the subreddit categories, 
# such as the names of brands.
related_words = {'pepsi', 'pepsico', 'coca', 'cola', 'coke'}

# Custom stop words are common English words that are meaningless, 
# and we also include related words to create a custom stop word list.

custom_stop_words = set(stopwords.words('english')).union(related_words)

# %%
# Instantiate Stemmer and Lemmatizer
stemmer = nltk.PorterStemmer()
lemmatizer = nltk.WordNetLemmatizer()

# Create 6 custom tokenizers. 
# Note that all tokenizers are designed to remove symbols, related words, and convert text to lowercase, 
# with the following additional functions:
# - lower_only: no other changes
# - lower_stop: removes stopwords
# - stem_only: applies stemming
# - stem_stop: applies stemming and removes stopwords
# - lem_only: applies lemmatizing
# - lem_stop: applies lemmatizing and removes stopwords

def lower_only(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [token for token in tokens if token not in related_words and token.isalpha()]

def lower_stop(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [token for token in tokens if token not in custom_stop_words and token.isalpha()]

def stem_only(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [stemmer.stem(token) for token in tokens if token not in related_words and token.isalpha()]

def stem_stop(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [stemmer.stem(token) for token in tokens if token not in custom_stop_words and token.isalpha()]

def lem_only(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [lemmatizer.lemmatize(token) for token in tokens if token not in related_words and token.isalpha()]

def lem_stop(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [lemmatizer.lemmatize(token) for token in tokens if token not in custom_stop_words and token.isalpha()]

# %%
# Custom metrics used in GridSearch results
scorers = {
    'accuracy': make_scorer(accuracy_score)
    , 'recall': make_scorer(recall_score, average = 'binary')
    , 'precision': make_scorer(precision_score, average = 'binary')
    , 'f1': make_scorer(f1_score, average = 'binary')
}

# %%
# GridSearch parameters
# 'vectorizer__' is used to set parameters for CountVectorizer and TfidfVectorizer.
# Since the tokenizer parameter is applied, we set 'token_pattern' to None.
params = {
    'vectorizer': [CountVectorizer(token_pattern = None)
                   , TfidfVectorizer(token_pattern = None)
                  ] 
    , 'vectorizer__tokenizer': [lower_only
                                , lower_stop
                                , stem_only
                                , stem_stop
                                , lem_only
                                , lem_stop
                               ] 
    , 'vectorizer__max_features': [3000
                                   , 5000
                                   , None
                                  ]
    , 'vectorizer__ngram_range': [(1, 1)                  # unigrams
                                  , (1, 2)                # unigrams and bigrams
                                 ]
    , 'vectorizer__min_df': [2, 3]
    , 'vectorizer__max_df': [0.8, 0.9]
    , 'classifier': [#MultinomialNB()
                     #, LogisticRegression()
                     #, KNeighborsClassifier()
                     #, DecisionTreeClassifier()
                     #, BaggingClassifier()
                     #, RandomForestClassifier()
                     #, AdaBoostClassifier(algorithm = 'SAMME')
                      GradientBoostingClassifier()
                     #, SVC()
                     #, XGBClassifier()
                    ]
}

# %%
# Create Pipeline
pipeline = Pipeline([
    ('vectorizer', CountVectorizer())                    # Will replace in GridSearch  
    , ('classifier', MultinomialNB())                    # Will replace in GridSearch 
])

# %%
# GridSearchCV
grid_search = GridSearchCV(pipeline
                           , param_grid=params
                           , cv = 5
                           , verbose = 3
                           , scoring = scorers
                           , refit = 'f1'
                           , return_train_score = True
)

# %%
# Fit the grid search

# Record start time
start_time =time.time()

with parallel_backend('threading', n_jobs=-1):
    grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.819, test=0.669) f1: (train=0.842, test=0.716) precision: (train=0.759, test=0.636) recall: (train=0.945, test=0.819) total time=   8.2s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.812, test=0.665) f1: (train=0.836, test=0.715) precision: (train=0.751, test=0.629) recall: (train=0.943, test=0.830) total time=   9.0s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.806, test=0.693) f1: (train=0.830, test=0.738) precision: (train=0.749, test=0.652) recall: (train=0.929, test=0.849) total time=   9.6s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.801, test=0.738) f1: (train=0.825, test=0.773) precision: (train=0.747, test=0.690) recall: (train=0.922, test=0.881) total time=  10.9s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.819, test=0.656) f1: (train=0.843, test=0.703) precision: (train=0.755, test=0.627) recall: (train=0.954, test=0.800) total time=  14.6s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.814, test=0.687) f1: (train=0.838, test=0.738) precision: (train=0.753, test=0.642) recall: (train=0.943, test=0.868) total time=  13.2s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.808, test=0.665) f1: (train=0.833, test=0.720) precision: (train=0.747, test=0.625) recall: (train=0.940, test=0.849) total time=  14.5s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.808, test=0.706) f1: (train=0.830, test=0.743) precision: (train=0.755, test=0.668) recall: (train=0.922, test=0.836) total time=  16.2s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.800, test=0.728) f1: (train=0.825, test=0.766) precision: (train=0.742, test=0.681) recall: (train=0.928, test=0.874) total time=  17.7s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.804, test=0.700) f1: (train=0.829, test=0.749) precision: (train=0.746, test=0.651) recall: (train=0.932, test=0.881) total time=  17.0s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.805, test=0.666) f1: (train=0.828, test=0.711) precision: (train=0.749, test=0.635) recall: (train=0.926, test=0.806) total time=  14.4s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.812, test=0.672) f1: (train=0.837, test=0.718) precision: (train=0.748, test=0.639) recall: (train=0.950, test=0.819) total time=  20.3s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.811, test=0.725) f1: (train=0.833, test=0.764) precision: (train=0.757, test=0.678) recall: (train=0.925, test=0.874) total time=  19.5s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.804, test=0.732) f1: (train=0.827, test=0.763) precision: (train=0.751, test=0.692) recall: (train=0.922, test=0.849) total time=  22.0s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.806, test=0.655) f1: (train=0.829, test=0.705) precision: (train=0.750, test=0.623) recall: (train=0.928, test=0.811) total time=  22.3s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.815, test=0.684) f1: (train=0.837, test=0.730) precision: (train=0.757, test=0.644) recall: (train=0.937, test=0.843) total time=  24.1s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=nan, test=nan) f1: (train=nan, test=nan) precision: (train=nan, test=nan) recall: (train=nan, test=nan) total time=   7.5s[CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=nan, test=nan) f1: (train=nan, test=nan) precision: (train=nan, test=nan) recall: (train=nan, test=nan) total time=   7.6s
#
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=nan, test=nan) f1: (train=nan, test=nan) precision: (train=nan, test=nan) recall: (train=nan, test=nan) total time=   7.9s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.822, test=0.738) f1: (train=0.844, test=0.778) precision: (train=0.762, test=0.682) recall: (train=0.945, test=0.906) total time=  32.3s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.801, test=0.668) f1: (train=0.826, test=0.713) precision: (train=0.744, test=0.635) recall: (train=0.928, test=0.811) total time=  33.1s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.798, test=0.741) f1: (train=0.821, test=0.771) precision: (train=0.747, test=0.701) recall: (train=0.912, test=0.855) total time=  25.2s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.800, test=0.681) f1: (train=0.824, test=0.727) precision: (train=0.748, test=0.643) recall: (train=0.917, test=0.836) total time=  21.1s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.812, test=0.653) f1: (train=0.833, test=0.698) precision: (train=0.757, test=0.627) recall: (train=0.926, test=0.787) total time=  14.9s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.812, test=0.716) f1: (train=0.834, test=0.757) precision: (train=0.758, test=0.668) recall: (train=0.926, test=0.874) total time=  16.0s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.812, test=0.659) f1: (train=0.837, test=0.707) precision: (train=0.748, test=0.629) recall: (train=0.951, test=0.806) total time=  26.1s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.812, test=0.684) f1: (train=0.837, test=0.733) precision: (train=0.751, test=0.642) recall: (train=0.945, test=0.855) total time=  18.4s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.811, test=0.661) f1: (train=0.833, test=0.709) precision: (train=0.757, test=0.629) recall: (train=0.925, test=0.811) total time=  16.8s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.789, test=0.738) f1: (train=0.813, test=0.775) precision: (train=0.738, test=0.688) recall: (train=0.904, test=0.887) total time=  16.8s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.808, test=0.687) f1: (train=0.833, test=0.737) precision: (train=0.747, test=0.643) recall: (train=0.940, test=0.862) total time=  16.3s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.819, test=0.672) f1: (train=0.843, test=0.716) precision: (train=0.756, test=0.640) recall: (train=0.953, test=0.812) total time=  19.1s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.828, test=0.700) f1: (train=0.849, test=0.749) precision: (train=0.765, test=0.651) recall: (train=0.953, test=0.881) total time=  18.2s[CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.806, test=0.703) f1: (train=0.831, test=0.741) precision: (train=0.747, test=0.665) recall: (train=0.936, test=0.836) total time=  15.4s
#
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.819, test=0.645) f1: (train=0.843, test=0.704) precision: (train=0.754, test=0.611) recall: (train=0.956, test=0.830) total time=  18.5s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.824, test=0.677) f1: (train=0.846, test=0.732) precision: (train=0.761, test=0.633) recall: (train=0.951, test=0.868) total time=  21.8s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.817, test=0.653) f1: (train=0.840, test=0.701) precision: (train=0.757, test=0.624) recall: (train=0.943, test=0.800) total time=  23.6s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.812, test=0.706) f1: (train=0.836, test=0.754) precision: (train=0.751, test=0.656) recall: (train=0.942, test=0.887) total time=  23.1s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.818, test=0.668) f1: (train=0.841, test=0.719) precision: (train=0.756, test=0.630) recall: (train=0.948, test=0.836) total time=  26.6s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.800, test=0.744) f1: (train=0.825, test=0.779) precision: (train=0.745, test=0.695) recall: (train=0.925, test=0.887) total time=  26.1s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.811, test=0.706) f1: (train=0.834, test=0.751) precision: (train=0.753, test=0.659) recall: (train=0.936, test=0.874) total time=  22.9s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.822, test=0.675) f1: (train=0.843, test=0.717) precision: (train=0.762, test=0.645) recall: (train=0.943, test=0.806) total time=  25.7s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.820, test=0.706) f1: (train=0.841, test=0.744) precision: (train=0.765, test=0.667) recall: (train=0.934, test=0.843) total time=  24.2s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.826, test=0.645) f1: (train=0.848, test=0.701) precision: (train=0.764, test=0.613) recall: (train=0.951, test=0.818) total time=  23.3s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.804, test=0.722) f1: (train=0.827, test=0.749) precision: (train=0.751, test=0.691) recall: (train=0.922, test=0.818) total time=  23.8s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.805, test=0.666) f1: (train=0.828, test=0.712) precision: (train=0.749, test=0.634) recall: (train=0.926, test=0.812) total time=  20.1s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.817, test=0.671) f1: (train=0.840, test=0.718) precision: (train=0.758, test=0.636) recall: (train=0.940, test=0.824) total time=  25.6s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.824, test=0.725) f1: (train=0.845, test=0.768) precision: (train=0.765, test=0.673) recall: (train=0.943, test=0.893) total time=  24.5s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.802, test=0.677) f1: (train=0.826, test=0.722) precision: (train=0.748, test=0.642) recall: (train=0.922, test=0.824) total time=  25.7s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.795, test=0.735) f1: (train=0.818, test=0.764) precision: (train=0.745, test=0.698) recall: (train=0.906, test=0.843) total time=  22.8s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.809, test=0.677) f1: (train=0.832, test=0.723) precision: (train=0.754, test=0.641) recall: (train=0.926, test=0.830) total time=  23.1s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.825, test=0.675) f1: (train=0.847, test=0.715) precision: (train=0.762, test=0.646) recall: (train=0.954, test=0.800) total time=  23.9s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.820, test=0.700) f1: (train=0.842, test=0.746) precision: (train=0.761, test=0.654) recall: (train=0.942, test=0.868) total time=  23.0s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.811, test=0.693) f1: (train=0.832, test=0.730) precision: (train=0.758, test=0.660) recall: (train=0.923, test=0.818) total time=  22.1s[CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.821, test=0.642) f1: (train=0.843, test=0.696) precision: (train=0.760, test=0.612) recall: (train=0.947, test=0.805) total time=  22.7s
#
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.817, test=0.712) f1: (train=0.837, test=0.750) precision: (train=0.766, test=0.672) recall: (train=0.923, test=0.849) total time=  23.1s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.816, test=0.650) f1: (train=0.838, test=0.696) precision: (train=0.760, test=0.624) recall: (train=0.932, test=0.787) total time=  21.4s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.809, test=0.728) f1: (train=0.832, test=0.766) precision: (train=0.754, test=0.681) recall: (train=0.926, test=0.874) total time=  20.0s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.809, test=0.668) f1: (train=0.832, test=0.714) precision: (train=0.753, test=0.634) recall: (train=0.929, test=0.818) total time=  16.9s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.799, test=0.735) f1: (train=0.820, test=0.769) precision: (train=0.753, test=0.690) recall: (train=0.900, test=0.868) total time=  17.2s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=2, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.813, test=0.700) f1: (train=0.835, test=0.740) precision: (train=0.757, test=0.660) recall: (train=0.932, test=0.843) total time=  16.6s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.817, test=0.653) f1: (train=0.841, test=0.701) precision: (train=0.753, test=0.624) recall: (train=0.953, test=0.800) total time=  14.0s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.812, test=0.696) f1: (train=0.834, test=0.738) precision: (train=0.756, test=0.657) recall: (train=0.929, test=0.843) total time=  14.1s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.808, test=0.674) f1: (train=0.833, test=0.724) precision: (train=0.747, test=0.635) recall: (train=0.942, test=0.843) total time=  14.5s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.803, test=0.738) f1: (train=0.826, test=0.772) precision: (train=0.748, test=0.692) recall: (train=0.923, test=0.874) total time=  15.7s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.816, test=0.681) f1: (train=0.839, test=0.731) precision: (train=0.755, test=0.638) recall: (train=0.943, test=0.855) total time=  17.1s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.815, test=0.672) f1: (train=0.838, test=0.715) precision: (train=0.754, test=0.642) recall: (train=0.942, test=0.806) total time=  15.4s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.805, test=0.687) f1: (train=0.830, test=0.735) precision: (train=0.747, test=0.645) recall: (train=0.932, test=0.855) total time=  17.2s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.814, test=0.661) f1: (train=0.838, test=0.710) precision: (train=0.753, test=0.628) recall: (train=0.943, test=0.818) total time=  19.6s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.798, test=0.741) f1: (train=0.823, test=0.772) precision: (train=0.743, test=0.699) recall: (train=0.922, test=0.862) total time=  17.5s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.803, test=0.709) f1: (train=0.828, test=0.753) precision: (train=0.745, test=0.662) recall: (train=0.931, test=0.874) total time=  18.8s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.812, test=0.672) f1: (train=0.837, test=0.718) precision: (train=0.748, test=0.639) recall: (train=0.950, test=0.819) total time=  19.6s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.818, test=0.712) f1: (train=0.837, test=0.749) precision: (train=0.767, test=0.673) recall: (train=0.922, test=0.843) total time=  19.8s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.806, test=0.668) f1: (train=0.829, test=0.713) precision: (train=0.750, test=0.635) recall: (train=0.928, test=0.811) total time=  20.9s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.796, test=0.735) f1: (train=0.821, test=0.765) precision: (train=0.744, test=0.696) recall: (train=0.915, test=0.849) total time=  20.3s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.810, test=0.674) f1: (train=0.833, test=0.718) precision: (train=0.754, test=0.640) recall: (train=0.929, test=0.818) total time=  21.6s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.804, test=0.669) f1: (train=0.829, test=0.713) precision: (train=0.747, test=0.639) recall: (train=0.931, test=0.806) total time=  25.2s[CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.819, test=0.735) f1: (train=0.840, test=0.775) precision: (train=0.762, test=0.681) recall: (train=0.936, test=0.899) total time=  24.6s
#
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.807, test=0.665) f1: (train=0.830, test=0.711) precision: (train=0.750, test=0.632) recall: (train=0.929, test=0.811) total time=  24.4s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.794, test=0.744) f1: (train=0.818, test=0.774) precision: (train=0.743, test=0.703) recall: (train=0.911, test=0.862) total time=  27.5s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.801, test=0.674) f1: (train=0.825, test=0.724) precision: (train=0.746, test=0.635) recall: (train=0.923, test=0.843) total time=  26.3s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.818, test=0.672) f1: (train=0.841, test=0.718) precision: (train=0.755, test=0.639) recall: (train=0.950, test=0.819) total time=  20.6s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.820, test=0.706) f1: (train=0.839, test=0.742) precision: (train=0.768, test=0.670) recall: (train=0.925, test=0.830) total time=  18.6s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.818, test=0.649) f1: (train=0.841, test=0.699) precision: (train=0.756, test=0.618) recall: (train=0.948, test=0.805) total time=  20.6s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.808, test=0.659) f1: (train=0.832, test=0.705) precision: (train=0.751, test=0.631) recall: (train=0.932, test=0.800) total time=  17.0s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.796, test=0.744) f1: (train=0.819, test=0.777) precision: (train=0.744, test=0.698) recall: (train=0.912, test=0.874) total time=  20.4s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_only at 0x00000236FE7A8EA0>; accuracy: (train=0.815, test=0.687) f1: (train=0.840, test=0.737) precision: (train=0.748, test=0.643) recall: (train=0.958, test=0.862) total time=  21.1s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.808, test=0.719) f1: (train=0.829, test=0.761) precision: (train=0.756, test=0.670) recall: (train=0.918, test=0.881) total time=  20.3s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.813, test=0.671) f1: (train=0.836, test=0.716) precision: (train=0.756, test=0.637) recall: (train=0.934, test=0.818) total time=  19.6s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.795, test=0.738) f1: (train=0.817, test=0.773) precision: (train=0.747, test=0.690) recall: (train=0.901, test=0.881) total time=  17.9s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 1), vectorizer__tokenizer=<function lem_stop at 0x00000236FE7A8F40>; accuracy: (train=0.805, test=0.693) f1: (train=0.828, test=0.739) precision: (train=0.751, test=0.651) recall: (train=0.923, test=0.855) total time=  18.0s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.823, test=0.659) f1: (train=0.845, test=0.704) precision: (train=0.759, test=0.632) recall: (train=0.953, test=0.794) total time=  19.1s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.828, test=0.687) f1: (train=0.848, test=0.735) precision: (train=0.767, test=0.645) recall: (train=0.948, test=0.855) total time=  16.1s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.812, test=0.709) f1: (train=0.835, test=0.747) precision: (train=0.754, test=0.670) recall: (train=0.936, test=0.843) total time=  15.3s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.821, test=0.642) f1: (train=0.845, test=0.702) precision: (train=0.755, test=0.608) recall: (train=0.959, test=0.830) total time=  17.8s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.819, test=0.643) f1: (train=0.841, test=0.694) precision: (train=0.760, test=0.617) recall: (train=0.942, test=0.794) total time=  17.5s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_only at 0x00000236FE7A8900>; accuracy: (train=0.821, test=0.677) f1: (train=0.845, test=0.729) precision: (train=0.757, test=0.636) recall: (train=0.956, test=0.855) total time=  20.2s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.813, test=0.671) f1: (train=0.837, test=0.722) precision: (train=0.753, test=0.632) recall: (train=0.940, test=0.843) total time=  20.3s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.815, test=0.687) f1: (train=0.838, test=0.738) precision: (train=0.755, test=0.642) recall: (train=0.940, test=0.868) total time=  21.2s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.796, test=0.735) f1: (train=0.821, test=0.773) precision: (train=0.744, test=0.684) recall: (train=0.915, test=0.887) total time=  23.4s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x00000236FE7A89A0>; accuracy: (train=0.809, test=0.700) f1: (train=0.833, test=0.747) precision: (train=0.751, test=0.653) recall: (train=0.934, test=0.874) total time=  23.1s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.822, test=0.678) f1: (train=0.843, test=0.720) precision: (train=0.764, test=0.647) recall: (train=0.939, test=0.812) total time=  25.1s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.824, test=0.728) f1: (train=0.844, test=0.763) precision: (train=0.768, test=0.685) recall: (train=0.937, test=0.862) total time=  26.9s
# [CV 1/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.809, test=0.682) f1: (train=0.832, test=0.724) precision: (train=0.753, test=0.649) recall: (train=0.929, test=0.819) total time=  18.0s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.818, test=0.649) f1: (train=0.841, test=0.703) precision: (train=0.757, test=0.616) recall: (train=0.945, test=0.818) total time=  27.4s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.810, test=0.709) f1: (train=0.833, test=0.738) precision: (train=0.754, test=0.681) recall: (train=0.929, test=0.805) total time=  28.6s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_only at 0x00000236FE7A8D60>; accuracy: (train=0.823, test=0.674) f1: (train=0.844, test=0.721) precision: (train=0.765, test=0.638) recall: (train=0.940, test=0.830) total time=  38.3s
# [CV 2/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.817, test=0.725) f1: (train=0.839, test=0.769) precision: (train=0.760, test=0.671) recall: (train=0.936, test=0.899) total time=  35.1s
# [CV 3/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.804, test=0.671) f1: (train=0.828, test=0.713) precision: (train=0.748, test=0.640) recall: (train=0.928, test=0.805) total time=  37.6s
# [CV 4/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.795, test=0.732) f1: (train=0.817, test=0.765) precision: (train=0.748, test=0.688) recall: (train=0.900, test=0.862) total time=  32.4s
# [CV 5/5] END classifier=GradientBoostingClassifier(), vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.8, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function stem_stop at 0x00000236FE7A8E00>; accuracy: (train=0.802, test=0.671) f1: (train=0.826, test=0.718) precision: (train=0.746, test=0.636) recall: (train=0.926, test=0.824) total time=  23.0s
# ...
#  0.95194751 0.93624547 0.94252342 0.92336868 0.94472419 0.92337065
#  0.93593545 0.93655994 0.93059546 0.92462358 0.93562049 0.92336769
#  0.94817985 0.93656043 0.93812979 0.92462506 0.94158842 0.92336967
#  0.93781878 0.93279129 0.93028248 0.92399712 0.93373617 0.92211329
#  0.8344522  0.83342168 0.83242352 0.83066454 0.83505847 0.82933431
#  0.84772994 0.83488814 0.8443906  0.8291316  0.84851073 0.8303408
#  0.83214898 0.83191938 0.83223305 0.82748167 0.8353452  0.82768318
#  0.84753736 0.8347932  0.84470191 0.82966204 0.84646616 0.82891412
#  0.87268268 0.86458578 0.87267111 0.8599185  0.87268527 0.86709194
#  0.87988119 0.86379608 0.88306698 0.8565547  0.87916972 0.86837616
#  0.87140099 0.86253826 0.87446421 0.85827668 0.87452626 0.86637527
#  0.87589695 0.86357541 0.88240948 0.85622447 0.88405325 0.86546458
#  0.87388765 0.8655396  0.8733679  0.85655051 0.87214506 0.8654354
#  0.8779098  0.86232863 0.8805937  0.85790965 0.88012837 0.86374949
#  0.8692955  0.86207983 0.87202264 0.85621269 0.87594693 0.86528591
#  0.88099389 0.86578021 0.88382571 0.8590354  0.88424607 0.86774215
#  0.87459551 0.86243686 0.87149393 0.85976439 0.87403227 0.8662087
#  0.88047087 0.86205255 0.88150138 0.85586767 0.88280754 0.86559096
#  0.87170142 0.86232812 0.8709172  0.85656207 0.87397276 0.86531009
#  0.87615739 0.86465389 0.88233276 0.8576274  0.88395456 0.86688121
#  0.87113326 0.86268882 0.87059112 0.860287   0.87508373 0.86478312
#  0.88000032 0.86419079 0.8803364  0.86034153 0.88087045 0.86666803
#  0.87188223 0.86307204 0.87280187 0.85903823 0.87415839 0.86470445
#  0.87884628 0.86553079 0.88266591 0.8557295  0.88211051 0.8680722
#  0.87301872 0.86433782 0.87246738 0.85833752 0.87442579 0.86440139
#  0.87808566 0.86252831 0.88330821 0.85498582 0.88279198 0.86270016
#  0.87210542 0.86167716 0.87434217 0.85691784 0.87565806 0.86597609
#  0.87760748 0.86420499 0.88212605 0.85949424 0.88398336 0.8676862
#  0.87224946 0.8657422  0.87084605 0.86112404 0.87455758 0.86847704
#  0.88047087 0.86289621 0.88373284 0.85589415 0.88287441 0.86790234
#  0.87335122 0.86392319 0.8747402  0.85771721 0.87427235 0.86544275
#  0.8787097  0.86440997 0.88227431 0.85910133 0.88395586 0.86399897]
#   warnings.warn(

# %%
# Record end time
end_time = time.time()

# Calculate elapsed time
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time:.4f} seconds")

# Time taken: 4522.0351 seconds  for xgboost
# Out:
# Time taken: 4437.6006 seconds

# %%
# Collect results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results.to_csv('../data/cv_results_gb.csv') 
# Display important metrics
cv_results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        11.951224      0.910323         2.033591        0.862367
# 1        11.831407      4.265018         0.579388        0.276554
# 2        18.754280      1.204162         2.971510        0.585754
# 3        24.379055      7.465999         0.944496        0.567476
# 4        13.130297      7.015924         0.471777        0.580527
# ..             ...           ...              ...             ...
# 283      13.178176      6.216785         0.524394        0.471759
# 284      26.129953      1.747220         3.614737        1.476485
# 285      19.888088     10.872776         1.510359        2.091426
# 286      21.877410      1.394613         1.628071        0.668358
# 287      11.082929      2.928988         0.373312        0.309542
#
#                  param_classifier                     param_vectorizer  \
# 0    GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
# 1    GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
# 2    GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
# 3    GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
# 4    GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
# ..                            ...                                  ...
# 283  GradientBoostingClassifier()  TfidfVectorizer(token_pattern=None)
# 284  GradientBoostingClassifier()  TfidfVectorizer(token_pattern=None)
# 285  GradientBoostingClassifier()  TfidfVectorizer(token_pattern=None)
# 286  GradientBoostingClassifier()  TfidfVectorizer(token_pattern=None)
# 287  GradientBoostingClassifier()  TfidfVectorizer(token_pattern=None)
#
#     param_vectorizer__max_df param_vectorizer__max_features  \
# 0                        0.8                           3000
# 1                        0.8                           3000
# 2                        0.8                           3000
# 3                        0.8                           3000
# 4                        0.8                           3000
# ..                       ...                            ...
# 283                      0.9                           None
# 284                      0.9                           None
# 285                      0.9                           None
# 286                      0.9                           None
# 287                      0.9                           None
#
#     param_vectorizer__min_df param_vectorizer__ngram_range  ... mean_test_f1  \
# 0                          2                        (1, 1)  ...     0.735552
# 1                          2                        (1, 1)  ...     0.736700
# 2                          2                        (1, 1)  ...     0.735884
# 3                          2                        (1, 1)  ...     0.739829
# 4                          2                        (1, 1)  ...          NaN
# ..                       ...                           ...  ...          ...
# 283                        3                        (1, 2)  ...     0.707965
# 284                        3                        (1, 2)  ...     0.706111
# 285                        3                        (1, 2)  ...     0.714203
# 286                        3                        (1, 2)  ...     0.697257
# 287                        3                        (1, 2)  ...     0.706624
#
#     std_test_f1  rank_test_f1  split0_train_f1  split1_train_f1  \
# 0      0.023590            58         0.843056         0.830269
# 1      0.019390            45         0.841737         0.829713
# 2      0.023719            54         0.837145         0.832509
# 3      0.028917            13         0.828411         0.843728
# 4           NaN           288         0.837370              NaN
# ..          ...           ...              ...              ...
# 283    0.019803           190         0.868140         0.868876
# 284    0.004610           202         0.880935         0.885965
# 285    0.014387           150         0.853087         0.867787
# 286    0.015942           246         0.876990         0.889868
# 287    0.022041           200         0.866187         0.871157
#
#      split2_train_f1  split3_train_f1  split4_train_f1  mean_train_f1  \
# 0           0.832523         0.825018         0.837631       0.833699
# 1           0.836465         0.824843         0.829030       0.832357
# 2           0.829474         0.827343         0.837307       0.832756
# 3           0.825996         0.821201         0.823695       0.828606
# 4                NaN              NaN         0.836692            NaN
# ..               ...              ...              ...            ...
# 283         0.858965         0.861051         0.865018       0.864410
# 284         0.886792         0.876274         0.881406       0.882274
# 285         0.853296         0.861091         0.860246       0.859101
# 286         0.888727         0.881798         0.882396       0.883956
# 287         0.870185         0.857558         0.854908       0.863999
#
#      std_train_f1
# 0        0.006189
# 1        0.005990
# 2        0.004003
# 3        0.007931
# 4             NaN
# ..            ...
# 283      0.003877
# 284      0.003810
# 285      0.005488
# 286      0.004761
# 287      0.006610
#
# [288 rows x 72 columns]
