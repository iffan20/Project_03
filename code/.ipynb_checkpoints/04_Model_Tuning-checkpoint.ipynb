# %% [markdown]
# ## ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Project 3: NLP Classification: Subreddit Pepsi vs Coca-Cola | Part 4: Model Tuning

# %% [markdown]
# ---
#
# [README](../README.md) | [Part 1: EDA](01_EDA.ipynb) | [Part 2: Vectorizer](02_Vectorizer.ipynb) | [Part 3: Vectorizer Performance](03_Vectorizer_Performance.ipynb) | **Part 4: Model Tuning**
#
# ---

# %% [markdown]
# ### Introduction
# From [Part 3: Vectorizer Performance](03_Vectorizer_Performance.ipynb), we learned about the impact of vectorizers, tokenizers, and their parameters on the model's accuracy. However, since we only used the default model settings, there is potential to improve performance by tuning the model's parameters. In this chapter, we will explore how to optimize the model by adjusting these parameters.

# %% [markdown]
# ### Import

# %%
# Data manipulation and plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# NLP tools
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
# nltk.download('punkt')

# Model selection and evaluation
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix, recall_score, precision_score, f1_score, ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Classifiers
from sklearn.naive_bayes import MultinomialNB 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# Time utility
import time
from joblib import parallel_backend

# Set seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ### Model Selection
# - The goal of the model is to predict outcomes effectively, so we select the model with the highest testing F1 score.
# - The chosen model is Gradient Boosting having **74.5% on F1 score**, which achieved an accuracy of **81.1% on the training set** and **69.9% on the testing set**.
# - Its parameters are as follows:
#     - Vectorizer: `CountVectorizer`
#     - Tokenization: Performed using **lowering**, with English **stopwords removed**
#     - Features: Unigrams and bigrams, with a maximum of `3000` features, `min_df = 3`, and `max_df = 0.9`

# %%
df1 = pd.read_csv('../data/cv_results_nb.csv')                       # Load Data Naive Bayes Performance
df2 = pd.read_csv('../data/cv_results_xgb.csv')                      # Load Data XGBoost Performance 
df3 = pd.read_csv('../data/cv_results_ada.csv')                      # Load Data AdaBoost Performance 
df4 = pd.read_csv('../data/cv_results_gb.csv')                       # Load Data GradientBoost Performance 
# Check shape
df1.shape, df2.shape, df3.shape, df4.shape
# Out:
# ((288, 73), (288, 73), (288, 73), (288, 73))

# %%
df = pd.concat([df1, df2, df3, df4], axis = 0, ignore_index = True)

columns = ['param_classifier' 
           , 'param_vectorizer'
           , 'param_vectorizer__tokenizer' 
           , 'param_vectorizer__max_features' 
           , 'param_vectorizer__ngram_range' 
           , 'param_vectorizer__min_df' 
           , 'param_vectorizer__max_df'
           , 'mean_train_accuracy' 
           , 'mean_test_accuracy'
           , 'mean_train_f1' 
           , 'mean_test_f1'
          ]

df = df[columns]

df.sort_values(by = 'mean_test_f1', ascending = False).head(1)
# Out:
#                  param_classifier                     param_vectorizer  \
# 955  GradientBoostingClassifier()  CountVectorizer(token_pattern=None)
#
#                      param_vectorizer__tokenizer  \
# 955  <function lower_stop at 0x00000236FE7A89A0>
#
#      param_vectorizer__max_features param_vectorizer__ngram_range  \
# 955                          3000.0                        (1, 2)
#
#      param_vectorizer__min_df  param_vectorizer__max_df  mean_train_accuracy  \
# 955                         3                       0.9             0.810983
#
#      mean_test_accuracy  mean_train_f1  mean_test_f1
# 955            0.699263       0.834754      0.745306

# %% [markdown]
# ### Model Tuning

# %%
# Set Features and Target

df = pd.read_csv('../data/subreddit_pepsi_vs_cocacola_clean.csv')          # Load Data
df.head(1)                                                                 # Check first row

X = df['title_body']
y = df['is_pepsi']

# Split the data to training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X
                                                    , y
                                                    , test_size = 0.2
                                                    , stratify = y
                                                   )

# %%
# Related words are words that can easily identify the subreddit categories, 
# such as the names of brands.
related_words = {'pepsi', 'pepsico', 'coca', 'cola', 'coke'}

# Custom stop words are common English words that are meaningless, 
# and we also include related words to create a custom stop word list.

custom_stop_words = set(stopwords.words('english')).union(related_words)

# %%
# Set Pipeline

def lower_stop(doc):
    doc = doc.lower()
    tokens = word_tokenize(doc)
    return [token for token in tokens if token not in custom_stop_words and token.isalpha()]

params = {
    # ----------------------------------------------------- Parameters of Vectorizer having maximum test's f1 score
    'vectorizer': [CountVectorizer(token_pattern = None)] 
    , 'vectorizer__tokenizer': [lower_stop] 
    , 'vectorizer__max_features': [3000]
    , 'vectorizer__ngram_range': [(1, 2)]
    , 'vectorizer__min_df': [3]
    , 'vectorizer__max_df': [0.9]
    # -----------------------------------------------------
    , 'classifier': [GradientBoostingClassifier()]
    , 'classifier__learning_rate': [1,0.1]
    , 'classifier__n_estimators': [100,200]
    , 'classifier__subsample': [0.8,1.0]
    , 'classifier__max_depth': [2,3,4]
}


# Default Parameter of GradientBoostingClassifier
# GradientBoostingClassifier(
#     *,
#     loss='log_loss',
#     learning_rate=0.1,
#     n_estimators=100,
#     subsample=1.0,
#     criterion='friedman_mse',
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_depth=3,
#     min_impurity_decrease=0.0,
#     init=None,
#     random_state=None,
#     max_features=None,
#     verbose=0,
#     max_leaf_nodes=None,
#     warm_start=False,
#     validation_fraction=0.1,
#     n_iter_no_change=None,
#     tol=0.0001,
#     ccp_alpha=0.0,
# )

# %%
# Custom metrics used in GridSearch results
scorers = {
    'accuracy': make_scorer(accuracy_score)
    , 'recall': make_scorer(recall_score, average = 'binary')
    , 'precision': make_scorer(precision_score, average = 'binary')
    , 'f1': make_scorer(f1_score, average = 'binary')
}

# %%
# Create Pipeline
pipeline = Pipeline([
    ('vectorizer', CountVectorizer())                    # Will replace in GridSearch  
    , ('classifier', MultinomialNB())                    # Will replace in GridSearch 
])

# %%
# GridSearchCV
grid_search = GridSearchCV(pipeline
                           , param_grid=params
                           , cv = 5
                           , verbose = 2
                           , scoring = scorers
                           , refit = 'f1'
                           , return_train_score = True
)

# %%
# Fit the grid search

# Record start time
start_time = time.time()

with parallel_backend('threading', n_jobs=-1):
    grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   3.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   2.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  12.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  15.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  14.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  18.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  23.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  22.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  14.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  12.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.9s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  15.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  14.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   3.2s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.3s[CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.3s
#
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=2, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.0s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  13.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   5.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=3, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  11.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   6.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=100, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.3s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=  10.6s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.1s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   8.4s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   7.5s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=0.8, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   9.7s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.8s
# [CV] END classifier=GradientBoostingClassifier(), classifier__learning_rate=0.1, classifier__max_depth=4, classifier__n_estimators=200, classifier__subsample=1.0, vectorizer=CountVectorizer(token_pattern=None), vectorizer__max_df=0.9, vectorizer__max_features=3000, vectorizer__min_df=3, vectorizer__ngram_range=(1, 2), vectorizer__tokenizer=<function lower_stop at 0x0000026CF53B9A80>; total time=   4.5s

# %%
# Record end time
end_time = time.time()

# Calculate elapsed time
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time:.4f} seconds")
# Out:
# Time taken: 155.2359 seconds

# %%
# Collect results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results.to_csv('../data/cv_results_gb_tuning.csv')

# %%
# Display important metrics
cv_results.sort_values(by = 'mean_test_f1', ascending = False).head(1)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17       6.633518      1.944292         0.246159        0.161637
#
#                 param_classifier param_classifier__learning_rate  \
# 17  GradientBoostingClassifier()                             0.1
#
#    param_classifier__max_depth param_classifier__n_estimators  \
# 17                           3                            100
#
#    param_classifier__subsample                     param_vectorizer  ...  \
# 17                         1.0  CountVectorizer(token_pattern=None)  ...
#
#    mean_test_f1 std_test_f1 rank_test_f1 split0_train_f1 split1_train_f1  \
# 17     0.738933    0.027039            1        0.840336        0.836592
#
#    split2_train_f1  split3_train_f1  split4_train_f1  mean_train_f1  \
# 17        0.839437         0.825934         0.827972       0.834054
#
#     std_train_f1
# 17      0.005963
#
# [1 rows x 76 columns]

# %%
# Display the best parameters (giving highest f1-score on testing set) and corresponding metrics

print(f"The Best parameters: {grid_search.best_params_}")
print(f"Testing F1 score: {grid_search.cv_results_['mean_test_f1'][grid_search.best_index_]:.3f}")
print(f"Training F1 score: {grid_search.cv_results_['mean_train_f1'][grid_search.best_index_]:.3f}")
print(f"Testing accuracy: {grid_search.cv_results_['mean_test_accuracy'][grid_search.best_index_]:.3f}")
print(f"Training accuracy: {grid_search.cv_results_['mean_train_accuracy'][grid_search.best_index_]:.3f}")
# Out:
# The Best parameters: {'classifier': GradientBoostingClassifier(), 'classifier__learning_rate': 0.1, 'classifier__max_depth': 3, 'classifier__n_estimators': 100, 'classifier__subsample': 1.0, 'vectorizer': CountVectorizer(token_pattern=None), 'vectorizer__max_df': 0.9, 'vectorizer__max_features': 3000, 'vectorizer__min_df': 3, 'vectorizer__ngram_range': (1, 2), 'vectorizer__tokenizer': <function lower_stop at 0x0000026CF53B9A80>}
# Testing F1 score: 0.739
# Training F1 score: 0.834
# Testing accuracy: 0.692
# Training accuracy: 0.811

# %%
# Rebuild the pipeline using the best parameters
best_params = grid_search.best_params_

pipeline.set_params(**best_params)

# Fit the model with the best parameters on the entire training dataset
pipeline.fit(X_train, y_train)

# Evaluate the model on the test set
test_accuracy = pipeline.score(X_test, y_test)
print(f"Final model testing accuracy: {test_accuracy:.3f}")
# Out:
# Final model testing accuracy: 0.679

# %%
# y_test -> True labels
y_pred = pipeline.predict(X_test)  # Predicted labels

# Calculate individual metrics
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# Print results
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.6465863453815262
# Recall: 0.8090452261306532
# F1 Score: 0.71875
# Accuracy: 0.6785714285714286

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot = True
            , fmt = 'd'
            , cmap = 'Blues'
           )
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.tight_layout()
#plt.savefig('../images/confusion_model.png', dpi = 300, bbox_inches = 'tight')
plt.show();

# %% [markdown]
# ### Sponsor Predictions

# %%
df_sponsors = pd.read_csv('../data/well_known_sponsors.csv')

# %%
# Predict from 'mission'

X_sponsors = df_sponsors['mission']
y_sponsors = df_sponsors['is_pepsi']

df_sponsors['predicted'] = pipeline.predict(X_sponsors)
df_sponsors
# Out:
#                            brands  \
# 0                   Olympic Games
# 1                  FIFA World Cup
# 2                             NBA
# 3                      McDonald's
# 4          Coca-Cola 600 (NASCAR)
# 5  NFL (National Football League)
# 6           UEFA Champions League
# 7  Pepsi Super Bowl Halftime Show
# 8   MTV Video Music Awards (VMAs)
# 9                           Lay's
#
#                                               vision  \
# 0  To inspire the world to be better through the ...
# 1   To unite and inspire the world through football.
# 2  To be the world’s most innovative and inclusiv...
# 3  To provide high-quality fast food to billions ...
# 4  To celebrate motorsport excellence and innovat...
# 5  To be the most popular and successful sports l...
# 6  To inspire and engage the world by delivering ...
# 7  To provide unforgettable entertainment during ...
# 8  To connect music and culture to a global audie...
# 9  To delight consumers with a wide variety of ta...
#
#                                              mission actual_sponsors  \
# 0  The mission of the Olympic Games is to promote...            Coke
# 1  The mission of FIFA is to develop the game, to...            Coke
# 2  The mission of the NBA is to inspire and enter...            Coke
# 3  McDonald's mission is to be its customers' fav...            Coke
# 4  To host the most exciting race in NASCAR, blen...            Coke
# 5  The NFL's mission is to unite fans through the...           Pepsi
# 6  To bring passion and unity to football fans wo...           Pepsi
# 7  To deliver world-class performances and connec...           Pepsi
# 8  To promote creativity and celebrate the best i...           Pepsi
# 9  To provide convenient and enjoyable snacks for...           Pepsi
#
#    is_pepsi  predicted
# 0         0          1
# 1         0          0
# 2         0          1
# 3         0          0
# 4         0          1
# 5         1          1
# 6         1          1
# 7         1          1
# 8         1          0
# 9         1          1

# %%
# df_sponsors['predicted'] = df_sponsors['predicted'].map({1: 'Pepsi', 0: 'Coca-Cola'})
# df_sponsors['actual_sponsors'] = df_sponsors['actual_sponsors'].map({'Pepsi': 'Pepsi', 'Coke': 'Coca-Cola'})
df_sponsors[['brands','mission','actual_sponsors','predicted']]
# Out:
#                            brands  \
# 0                   Olympic Games
# 1                  FIFA World Cup
# 2                             NBA
# 3                      McDonald's
# 4          Coca-Cola 600 (NASCAR)
# 5  NFL (National Football League)
# 6           UEFA Champions League
# 7  Pepsi Super Bowl Halftime Show
# 8   MTV Video Music Awards (VMAs)
# 9                           Lay's
#
#                                              mission actual_sponsors  \
# 0  The mission of the Olympic Games is to promote...       Coca-Cola
# 1  The mission of FIFA is to develop the game, to...       Coca-Cola
# 2  The mission of the NBA is to inspire and enter...       Coca-Cola
# 3  McDonald's mission is to be its customers' fav...       Coca-Cola
# 4  To host the most exciting race in NASCAR, blen...       Coca-Cola
# 5  The NFL's mission is to unite fans through the...           Pepsi
# 6  To bring passion and unity to football fans wo...           Pepsi
# 7  To deliver world-class performances and connec...           Pepsi
# 8  To promote creativity and celebrate the best i...           Pepsi
# 9  To provide convenient and enjoyable snacks for...           Pepsi
#
#    predicted
# 0      Pepsi
# 1  Coca-Cola
# 2      Pepsi
# 3  Coca-Cola
# 4      Pepsi
# 5      Pepsi
# 6      Pepsi
# 7      Pepsi
# 8  Coca-Cola
# 9      Pepsi
